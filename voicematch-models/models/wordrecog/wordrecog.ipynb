# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

processor = Wav2Vec2Processor.from_pretrained(
    "facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base-960h")

processor.save_pretrained("model")
model.save_pretrained("model")

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

processor = Wav2Vec2Processor.from_pretrained(
    "model")
model = Wav2Vec2ForCTC.from_pretrained(
    "model")
# Out:
# 2023-03-11 13:34:44.914290: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-11 13:34:45.018824: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import json
import secrets

import sagemaker
from datasets import Audio, Dataset, interleave_datasets
from pydub import AudioSegment
from model.code.inference import input_fn, model_fn, predict_fn

model_dir = "model"
print(model_dir)

model = model_fn(model_dir)

ogg_audio = '../../data/hello-hello.ogg'

with open(ogg_audio, 'rb') as f:
    audio_data = f.read()
print(audio_data)

input_data = input_fn(audio_data, "audio/ogg")
print('input_data: ', input_data)

words = predict_fn(input_data, model)
print('words: ', words)

# output_data = output_fn(words, "application/json")
# print('output_data: ', words)

# output = json.dumps(words)
# print('output: ', output)
# Out:
# model
# loading model from model
# b'\x1aE\xdf\xa3\x9fB\x86\x81\x01B\xf7\x81\x01B\xf2\x81\x04B\xf3\x81\x08B\x82\x84webmB\x87\x81\x04B\x85\x81\x02\x18S\x80g\x01\xff\xff\xff\xff\xff\xff\xff\x15I\xa9f\x99*\xd7\xb1\x83\x0fB@M\x80\x86ChromeWA\x86Chrome\x16T\xaek\xbf\xae\xbd\xd7\x81\x01s\xc5\x87\x9f\xe0\xe1\xf3S\xec\x8a\x83\x81\x02\x86\x86A_OPUSc\xa2\x93OpusHead\x01\x02\x00\x00\x80\xbb\x00\x00\x00\x00\x00\xe1\x8d\xb5\x84G;\x80\x00\x9f\x81\x02bd\x81 \x1fC\xb6u\x01\xff\xff\xff\xff\xff\xff\xff\xe7\x81\x00\xa3A\x9b\x81\x00\x00\x80\xff\x83\x02\x02\xff\xfe\xff\xfev\xc2\xf5MEe\xed\xf8Bo\xee\x99\xd8b\x83a\xaa\x96\xeb\x93\x7f\x15\xff\x8a\x0cE\x9ffT\x95\x89\xa5\xda\'\x91\x14\x12\xffb(\x1b\xc4A\x08\xdb\x16\xf0\xc3p\xd7\x817\x081\xcd\xeb\x08\x86?\xdf\x17.\xe7\xd9\x81\xff\x86\x9cA\x12\xe4\xd0\xa4\xb6\xd0M\xbc\x12\xda\xe8\xf9+\xa7\xbf\xc05\xa6<PcU\x16A\x8b\x90\xbf\x10lE\xf8]i\xb8\x1f\x7fi\xa9a"\x95\x90@&\x9a\x86\xb0\xe9D\xe8\xa0\xbd\xabj>\xea\xde\x13\xc9M\xb5\x13\xba7\xb8wy\xa5G\xe4,P\xe2\xcb\xc8\xc3\xfd\x05\xd1\x88\x1b\x1f{\x0f\x92l>\xb5\xe6\x9d5\xf9\xa5\x7f\xe3\x1c\xcf\x11\xdc\xfcL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03k\xf5\xa9\xa3\x19\x16\xc3\xa3\xb2[\x8e\xcf\x18|\xbbdZ\x01\xb4\x04L\x16R\xff^\x83RbEpo\xbe}\xa3^_\xb0\xe7\x80<\x0bf\xef\x85\xd5\n\xd8\x8aN\xc5qcj\t\xe5\xad\xea\x8a\xaa\xdeQ\xe0X\xc5\xae%!\x1as@\x89 \xfa-.\xb8\xb1\xeb\xb8\x07\x06\xc8r\xec\xad\xdb\xf1e\xf7%\xce\x88\xaf}\x9d3eH\xcf4\xc6SL\xbc\x1c\x9f\x1fT\xbd>\xf4\xb8\x9aR\xc1\x15\xed\x7f\x17\xf5/a\xd6)-\xa3\xb7\x15t9\xf5\xc4?l;\xac\xa7\xd1\x01\xe2\xe52\xd06F\xf1\xd0\xf3\'=5\xcd\\N\xad\xc27\xa8\x87\xb8\x81\x0f\xa9N`4\xbc\x04\x93(\x05)\x94\x91\x84k\x06\xdb\xfc\xbcV\xeb\xcb\xd2\x11\xe83\xd0*\xb4\xc2\x94.\x98\x969\x96{6\x83h}rs`\xb4\x83\x95\xba\x8au\xa3B\xb8\x81\x003\x80\xff\x83\xe4\xe5\x16X\x00\xbe\xeej\x1e\xd6\xd9I-M-\xd9gb;\x04\\\xc0\x81\xe53\x00\xa4\xa39\xad&\rC\xab\xce\xa5\xe1\xa8\xc7\x96\xaa\x10\xeda\x00M^\xe4O\x90\x94\xe7\xed\x91\x8d4\x13>\xd3\x8c\xcc\xd2}B\xa7{Y4\xd4\x93&\xdd\xed\x93\xd4\xed\xd7\xd1\x8fQ\x0f\xb1\xedv\x05\xec7\xfa\x03\x1blP\xb7$>r\xda\x12\xc2\xdb\x16\xa6\xec\xc5\xdb\xe6\xb7p\x87\x9c\xa0\xd3\x04\xd9\xb6\xc9\xb1\x9d\x101\x82\tg\x99\x12\x9d\xfd\x00\xb6ar\xdd\xbe\xd2P\xb0\xa7\xf9\xff<\x0eR=\x03\x01D$\x87\xebKf\xb1\xfa\xabH}\xa9\xfc\x14\xca\x0e}\x05\xa9\xd8\xab\x88y1\xfa\xa4Q}\xdaS\xbd\xb0^?\x19\xf9O\xb6\x8cq\x04\x16\xe6Ol\t\xc7E\x93z7\x0c\xb7\xb2\'\xc1VMe\x86\xac\xad\xd9\x1fv\xae\xd06D\x96\xa6|\xec&\xc7S\x9a\x1b\xabNS\xe0\x07?\x13>_sA3\xe0XL\x9e\x96\xae\xaf\x13\xacg]RB\x08\x82\x16\x80|\xd7v\xa1\x8e\x1b\xb93v\xda\x97m\xd1\xce\xbew\xba\x9es\x17\xda\xc7\x1f\xf0\x8c7\x082\n\xca=\x92\x9ba\xb2\x00\x9e\xab\x89\xb9*\x1a(\xf8\xcc\xdb\x00I:\xc5<\x95l\xaeKW\xbc\xd1\x18|^&\xd95!\x8f\xc6\xce\xf2J\xd4\x88\xa3G4\xb1\xff\xcf:}\x83\xf8\xd65=\xb7YA\xc6\xe5\x7f9Ufn\xafd\xea#\xb36\x99O\xee\t$\x90\x98\x08+@\xb62\x80\x9a\r\x04RA\xee\xae\xd8\xfb%\xd4\x88\x11\xfa\xd1\x15\xca\x1b&h\xc0"\x0f\xe4/\xb9\x9d?j\n1\xe2\xd7R)^A\xbd\xf3Y\xef\xacK/\x1dD\xcaE\x81\xaeB\x98\x9f\xf9\x7fZbf\x80\x12\x9d\xbc8\xd3\xe0?\xdel~DlQ\xa8\xa1\xa4B\x0eq\x97\xa0\x01\x07\x1e1Q%\xb9\xdc2\x193\xf5\x0c\x1dMg\x08?\x16M]\xc1\xf5}\xfa\xc8\xfa\xd2\xa1\x16v8G92\\\x1b\x9d\xb4*\x86{p\xdf\x91n\xf1\xea\x98\xcb5[\x95\x8cfi$\xd2dm\xab\xca\xb0\xb9r-\xc4\x9du\x9b\xb6J\x9d\xa2x\xcf\x03@O\x81\xae\x85KN8\x7f\x9e\x82\xdd\x03\\\xc4\x98<\xf0\xd8\xb3&p\xedf\xa9~\x8d\x82\xfb\xe5\x9f\xe4\xf6\xa6-j\x82\xf8\xe2\xe2mB\x93\'qu\x95\x98\x1b\xa7^q\x94\xd0\xbc\x87\xb0\x01;\x86\xd4\x9c\xe2A\x1f\x7ff\xe7M\x9arrc\xb1\x95=f`\x88[\xb0\xfb!d\xde7@}M\xd9\x8eMR\xe7\x7fp\x86\x12\xbd\xbc\xef\xe93q\xb8R\xbf\x0c\xee*R\x1f\x18\x13\x1dD?c\x87\x0f\xa3\x7f\xf0t\xf8\xdd\xc8os\xc0\x0e\xca\xeb[\x7f\xce}\x07=\x1c8\x9b\xe4-\x94\x94\x0b\x86\xfc\xa9\xd4\xbe\xf5\xd8\xf8\xcf\x87\xb7\xed\xceX\x11\x14\xd9>\x815\xa3B\xc1\x81\x00w\x80\xff\x83\xe9\xe9\x1d\xa8\x00\x9e\xc4L\xf5\xc2\\\x14\xaa\xa0\xdd\x8dV\xbbt\x10R`\xadx\x81\xef\xbd%\x15\xb9\x9b\xc9\xc2;M\xba\x9c\xa3I\xf5\xb3[O4Q\xec+\xb0=\xd5!\x89\x11?{\x0f\xb5\xd9\x19\x9c5W8\xfe\x8c\x8f\x8d\x8b\x83\xc9@g\xec\xf7\xb3dC{\x8e\x99\xcc\xf ...
# saving file for processing: /tmp/vm-fc880bc87785517ad0e22af7380e7af27a009d816484e25f.ogg, with 43433 bytes, and audio/ogg content type
# file to be procesesed: /tmp/vm-fc880bc87785517ad0e22af7380e7af27a009d816484e25f.wav, $16000 Hz
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# input_data:  {'path': '/tmp/vm-fc880bc87785517ad0e22af7380e7af27a009d816484e25f.wav', 'array': array([0.        , 0.        , 0.        , ..., 0.01180409, 0.01161674,
#        0.00980848], dtype=float32), 'sampling_rate': 16000}
# predicting phonemes from /tmp/vm-fc880bc87785517ad0e22af7380e7af27a009d816484e25f.wav
# words predicted: ['HELLO HELLO ALWAYS AT GOING']
# words:  [{'word': 'HELLO', 'start_time': 0.66, 'end_time': 0.9}, {'word': 'HELLO', 'start_time': 1.04, 'end_time': 1.42}, {'word': 'ALWAYS', 'start_time': 1.86, 'end_time': 2.08}, {'word': 'AT', 'start_time': 2.16, 'end_time': 2.22}, {'word': 'GOING', 'start_time': 2.28, 'end_time': 2.68}]

# %%
# %cd /root/ws/ml/dlc/voicematch-dlc

# %rm -rf "model/"
# %mkdir "model/"

# !rsync -av --exclude '__pycache__' src/ model/code
# !du -sh "model"

# excluding the model with configs as it's very heavy with intention to load dynamically for inference and cache
# !tar zcvf model-v3.tar.gz --exclude='__pycache__' --exclude='__init__.py'  --exclude='pytorch_model.bin'  --exclude='config.json' --exclude='./model.tar.gz' .
# %mv "model/pytorch_model.bin" "model/voicematch.pt"
# !tar zcvf build/wordrecog.tar.gz --exclude='__pycache__' --exclude='__init__.py' --exclude='pytorch_model.bin' -C 'models/wordrecog/model' .

# !du -sh build/wordrecog.tar.gz

# !tar zcvf "voicematch-bin.tar.gz" --exclude='__pycache__' --exclude='__init__.py' -C './model-bin' .
# Out:
# 361M	models/wordrecog/model
# ./
# ./tokenizer_config.json
# ./vocab.json
# ./config.json
# ./code/
# ./code/inference.py
# ./preprocessor_config.json
# ./special_tokens_map.json
# 4.0K	build/voicematch-model.tar.gz

# %%
import sagemaker

sess = sagemaker.Session()
# sagemaker session bucket -> used for uploading data, models and logs
# sagemaker will automatically create this bucket if it not exists
sagemaker_session_bucket = None
if sagemaker_session_bucket is None and sess is not None:
    # set to default bucket if a bucket name is not given
    sagemaker_session_bucket = sess.default_bucket()

# try:
#     role = sagemaker.get_execution_role()
# except ValueError:
#     iam = boto3.client('iam')
#     role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

role = "arn:aws:iam::908060038426:role/sagemaker-local-role"

sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker role arn: arn:aws:iam::908060038426:role/sagemaker-local-role
# sagemaker bucket: sagemaker-us-east-1-908060038426
# sagemaker session region: us-east-1

# %%
model_s3_path = sess.upload_data(
    path="build/voicematch-model.tar.gz", bucket=sess.default_bucket(), key_prefix="model/voicematch"
)
print(f"model_s3_path: {model_s3_path}")
# Out:
# model_s3_path: s3://sagemaker-us-east-1-908060038426/model/voicematch/voicematch-model.tar.gz

# %%
# %load_ext autoreload
# %autoreload all

from sagemaker.huggingface.model import HuggingFaceModel
from sagemaker.pytorch import PyTorchModel
from src.predictor import PlainPyTorchPredictor

# print(f"model_s3_path: {model_s3_path}")
role = "arn:aws:iam::908060038426:role/sagemaker-local-role"
model_s3_path = "s3://sagemaker-us-east-1-908060038426/model/voicematch/voicematch-model.tar.gz"

# authenticate to ECR
# !aws ecr get-login-password --region us-west-2 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-west-2.amazonaws.com
# !docker pull 763104351884.dkr.ecr.us-west-2.amazonaws.com/djl-inference:0.21.0-deepspeed0.8.0-cu117

# model = HuggingFaceModel(
#    model_data=model_s3_path,
#    role=role,
# #    transformers_version="4.12",
# #    pytorch_version="1.9",
# #    py_version='py38',
#    image_uri="763104351884.dkr.ecr.us-west-2.amazonaws.com/djl-inference:0.21.0-deepspeed0.8.0-cu117",
# )

model = PyTorchModel(
    entry_point="inference.py",
    source_dir="src/wordrecog",
    role=role,
    model_data=model_s3_path,
    model_server_workers=4,
    image_uri='voicematch-wordrecog:latest',
    # predictor_cls=PlainPyTorchPredictor
)

from sagemaker.serializers import IdentitySerializer
from sagemaker.deserializers import StreamDeserializer

# !docker rm $(docker stop $(docker ps -aq --filter ancestor=voicematch-wordrecog:latest --format="{{.ID}}"))
# predictor.delete_endpoint()

predictor = model.deploy(
    initial_instance_count=1,
    instance_type="local",
    serializer=IdentitySerializer(),
    deserializer=StreamDeserializer(),
    # wait=False,
)
print(f"predictor: {predictor}")
print(f"predictor.endpoint_name: {predictor.endpoint_name}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Attaching to wbs0vskpmy-algo-1-5m0wn
# wbs0vskpmy-algo-1-5m0wn | Exported: /opt/ml/model/pytorch_model.bin
# wbs0vskpmy-algo-1-5m0wn | ['torchserve', '--start', '--model-store', '/.sagemaker/ts/models', '--ts-config', '/etc/sagemaker-ts.properties', '--log-config', '/opt/conda/lib/python3.9/site-packages/sagemaker_pytorch_serving_container/etc/log4j2.xml', '--models', 'model=/opt/ml/model']
# wbs0vskpmy-algo-1-5m0wn | WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# wbs0vskpmy-algo-1-5m0wn | Warning: Nashorn engine is planned to be removed from a future JDK release
# wbs0vskpmy-algo-1-5m0wn | Warning: Nashorn engine is planned to be removed from a future JDK release
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,396 [INFO ] main org.pytorch.serve.servingsdk.impl.PluginsManager - Initializing plugins manager...
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,591 [INFO ] main org.pytorch.serve.ModelServer -
# wbs0vskpmy-algo-1-5m0wn | Torchserve version: 0.7.0
# wbs0vskpmy-algo-1-5m0wn | TS Home: /opt/conda/lib/python3.9/site-packages
# wbs0vskpmy-algo-1-5m0wn | Current directory: /
# wbs0vskpmy-algo-1-5m0wn | Temp directory: /home/model-server/tmp
# wbs0vskpmy-algo-1-5m0wn | Metrics config path: /opt/conda/lib/python3.9/site-packages/ts/configs/metrics.yaml
# wbs0vskpmy-algo-1-5m0wn | Number of GPUs: 0
# wbs0vskpmy-algo-1-5m0wn | Number of CPUs: 24
# wbs0vskpmy-algo-1-5m0wn | Max heap size: 8000 M
# wbs0vskpmy-algo-1-5m0wn | Python executable: /opt/conda/bin/python3.9
# wbs0vskpmy-algo-1-5m0wn | Config file: /etc/sagemaker-ts.properties
# wbs0vskpmy-algo-1-5m0wn | Inference address: http://0.0.0.0:8080
# wbs0vskpmy-algo-1-5m0wn | Management address: http://0.0.0.0:8080
# wbs0vskpmy-algo-1-5m0wn | Metrics address: http://127.0.0.1:8082
# wbs0vskpmy-algo-1-5m0wn | Model Store: /.sagemaker/ts/models
# wbs0vskpmy-algo-1-5m0wn | Initial Models: model=/opt/ml/model
# wbs0vskpmy-algo-1-5m0wn | Log dir: /logs
# wbs0vskpmy-algo-1-5m0wn | Metrics dir: /logs
# wbs0vskpmy-algo-1-5m0wn | Netty threads: 0
# wbs0vskpmy-algo-1-5m0wn | Netty client threads: 0
# wbs0vskpmy-algo-1-5m0wn | Default workers per model: 2
# wbs0vskpmy-algo-1-5m0wn | Blacklist Regex: N/A
# wbs0vskpmy-algo-1-5m0wn | Maximum Response Size: 6553500
# wbs0vskpmy-algo-1-5m0wn | Maximum Request Size: 6553500
# wbs0vskpmy-algo-1-5m0wn | Limit Maximum Image Pixels: true
# wbs0vskpmy-algo-1-5m0wn | Prefer direct buffer: false
# wbs0vskpmy-algo-1-5m0wn | Allowed Urls: [file://.*|http(s)?://.*]
# wbs0vskpmy-algo-1-5m0wn | Custom python dependency for model allowed: false
# wbs0vskpmy-algo-1-5m0wn | Metrics report format: prometheus
# wbs0vskpmy-algo-1-5m0wn | Enable metrics API: true
# wbs0vskpmy-algo-1-5m0wn | Workflow Store: /.sagemaker/ts/models
# wbs0vskpmy-algo-1-5m0wn | Model config: N/A
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,596 [INFO ] main org.pytorch.serve.servingsdk.impl.PluginsManager -  Loading snapshot serializer plugin...
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,606 [INFO ] main org.pytorch.serve.ModelServer - Loading initial models: /opt/ml/model
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,608 [WARN ] main org.pytorch.serve.archive.model.ModelArchive - Model archive version is not defined. Please upgrade to torch-model-archiver 0.2.0 or higher
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,608 [WARN ] main org.pytorch.serve.archive.model.ModelArchive - Model archive createdOn is not defined. Please upgrade to torch-model-archiver 0.2.0 or higher
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,609 [INFO ] main org.pytorch.serve.wlm.ModelManager - Model model loaded.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,618 [INFO ] main org.pytorch.serve.ModelServer - Initialize Inference server with: EpollServerSocketChannel.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,682 [INFO ] main org.pytorch.serve.ModelServer - Inference API bind to: http://0.0.0.0:8080
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,682 [INFO ] main org.pytorch.serve.ModelServer - Initialize Metrics server with: EpollServerSocketChannel.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,684 [INFO ] main org.pytorch.serve.ModelServer - Metrics API bind to: http://127.0.0.1:8082
# wbs0vskpmy-algo-1-5m0wn | Model server started.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:18,809 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - worker pid is not available yet.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,318 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9000
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,321 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.9/site-packages/ts/configs/metrics.yaml.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,321 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - [PID]100
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,321 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Torch worker started.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,321 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Python runtime: 3.9.13
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,326 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9000
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,332 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9000.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,335 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Flushing req. to backend at: 1678338139335
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,358 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,369 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9001
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,373 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.9/site-packages/ts/configs/metrics.yaml.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,373 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - [PID]99
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,373 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Torch worker started.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,373 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Python runtime: 3.9.13
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,373 [INFO ] W-9001-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9001
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,376 [INFO ] W-9001-model_1.0 org.pytorch.serve.wlm.WorkerThread - Flushing req. to backend at: 1678338139376
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,376 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9001.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:19,394 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:21,166 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 1808
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:21,170 [INFO ] W-9001-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 1762
# !predictor: <sagemaker.pytorch.model.PyTorchPredictor object at 0x7f31b6e69db0>
# predictor.endpoint_name: voicematch-wordrecog-2023-03-09-05-02-15-758

# %%
from datasets import Audio, Dataset, interleave_datasets
from pydub import AudioSegment

print(predictor)

ogg_audio = '../../data/hello-hello.ogg'
with open(ogg_audio, 'rb') as f:
    audio_data = f.read()

# res = predictor.predict(audio_data, initial_args={
#     "ContentType": "audio/ogg",
# })
# predictor.content_type = "audio/ogg"
result = predictor.predict(audio_data)

print('len: ', len(result))
if len(result) > 0:
    print(f"result[0]: {result[0]}")
if len(result) > 1:
    print(f"result[1]: {result[1]}")

if len(result) > 0:
    response = result[0]
    status = response.status
    content_type = response.headers['Content-Type']
    data = response.read()

    print(f"status: {status}")
    print(f"content_type: {content_type}")
    print(f"data: {data}")
# Out:
# <sagemaker.pytorch.model.PyTorchPredictor object at 0x7f31b6e69db0>
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:51,178 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Flushing req. to backend at: 1678338171178
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:51,180 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - running model_fn
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:51,180 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Backend received inference at: 1678338171
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:55,339 [WARN ] W-9000-model_1.0-stderr MODEL_LOG - It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:55,643 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - running input_fn, content_type: application/octet-stream
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:55,643 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - ogg_file: /tmp/vm-1286b1fc44ff2d9a0609f0edc1da18b9d629943b4563e5ff.ogg
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:55,643 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - running predict_fn
# wbs0vskpmy-algo-1-5m0wn | 2023-03-09T05:02:55,643 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 4464
# len:  2
# result[0]: <urllib3.response.HTTPResponse object at 0x7f31b46b7250>
# result[1]: */*
# status: 200
# content_type: application/json
# data: b'[{"word": "HELLO", "start_time": 0.66, "end_time": 0.9}, {"word": "HELLO", "start_time": 1.04, "end_time": 1.42}, {"word": "ALWAYS", "start_time": 1.86, "end_time": 2.08}, {"word": "AT", "start_time": 2.16, "end_time": 2.22}, {"word": "GOING", "start_time": 2.28, "end_time": 2.68}]'

# %%
# delete endpoint
predictor.delete_endpoint()
# Out:
# Gracefully stopping... (press Ctrl+C again to force)
